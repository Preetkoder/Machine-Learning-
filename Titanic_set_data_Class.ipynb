# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
titanic = pd.read_csv('https://github.com/sukhioo7/dataset/blob/main/titanic.csv?raw=true')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# sorting up data and it use

titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#sorting Age data from NaN
titanic['Age'].fillna(titanic['Age'].mean(),inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Plotting graphs to see there trends ..
plt.figure(figsize=(18,7))
sns.barplot(x=titanic['Pclass'],y=titanic["Age"])

# Above graph is refering that people who are using first class is of age above 35
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
plt.figure(figsize=(18,7))
sns.boxplot(x=titanic['Pclass'],y=titanic["Age"],hue=titanic['Gender'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
# Now usign Groupby statement.
`
# Out:
#         PassengerId  Survived   Age  SibSp  Parch      Fare
# Pclass
# 1             447.0       1.0  32.5    0.0    0.0  82.66455
# 2             439.5       1.0  28.5    0.0    0.0  22.00000
# 3             376.0       0.5  28.0    0.0    0.0  12.47500

# %%
titanic[titanic['Gender'] =='male'].groupby('Pclass').median(numeric_only=True)
# Out:
#         PassengerId  Survived        Age  SibSp  Parch     Fare
# Pclass
# 1             480.5       0.0  36.000000    0.0    0.0  41.2625
# 2             416.5       0.0  29.699118    0.0    0.0  13.0000
# 3             466.0       0.0  29.699118    0.0    0.0   7.9250

# %%
titanic.groupby(['Gender','Pclass']).median(numeric_only=True)
# Out:
#                PassengerId  Survived        Age  SibSp  Parch      Fare
# Gender Pclass
# female 1             447.0       1.0  32.500000    0.0    0.0  82.66455
#        2             439.5       1.0  28.500000    0.0    0.0  22.00000
#        3             376.0       0.5  28.000000    0.0    0.0  12.47500
# male   1             480.5       0.0  36.000000    0.0    0.0  41.26250
#        2             416.5       0.0  29.699118    0.0    0.0  13.00000
#        3             466.0       0.0  29.699118    0.0    0.0   7.92500

# %%
#

def fill_age(row):
    pclass = row[0]
    gender = row[1]
    age = row[2]
    if pd.isnull(age):
        if pclass == 1:
            if gender == 'male':
                return 40
            else:
                return 35
        elif pclass==2:
            if gender == 'male':
                return 30
            else:
                return 28
        elif pclass == 3:
            if gender == 'male':
                return 25
            else:
                return 21
    else:
        return age

# %% [markdown]
# 4

# %%
titanic[['Pclass','Gender','Age']].apply(fill_age,axis=1)
# output we got is ser
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Length: 891, dtype: float64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def fill_null(Cabin):
    if pd.isnull(Cabin):
        return 0
    else:
        return 1

# %%
titanic['Cabin'] = titanic['Cabin'].apply(fill_null)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
plt.figure(figsize=(18,7))
sns.barplot(x=titanic['Cabin'],y=titanic["Age"],hue=titanic['Gender'])
# Out:
# <Axes: xlabel='Cabin', ylabel='Age'>

# %%
plt.figure(figsize=(18,7))
sns.boxplot(x=titanic['Cabin'],y=titanic["Age"],hue=titanic['Gender'])
# Out:
# <Axes: xlabel='Cabin', ylabel='Age'>

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  Cabin Embarked
# 0      0         A/5 21171   7.2500      0        S
# 1      0          PC 17599  71.2833      1        C
# 2      0  STON/O2. 3101282   7.9250      0        S
# 3      0            113803  53.1000      1        S
# 4      0            373450   8.0500      0        S

# %%
# confirm as if there is null value left

titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Gender         0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
titanic.dropna(inplace=True)

# %%
titanic.reset_index(drop=True,inplace=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  Cabin Embarked
# 0      0         A/5 21171   7.2500      0        S
# 1      0          PC 17599  71.2833      1        C
# 2      0  STON/O2. 3101282   7.9250      0        S
# 3      0            113803  53.1000      1        S
# 4      0            373450   8.0500      0        S

# %%
titanic['Parch']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 884    0
# 885    0
# 886    2
# 887    0
# 888    0
# Name: Parch, Length: 889, dtype: int64

# %%
titanic.drop(["PassengerId","Name","Ticket"],axis=1,inplace=True)

# %%
titanic.head()
# Out:
#    Survived  Pclass  Gender   Age  SibSp  Parch     Fare  Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500      0        S
# 1         1       1  female  38.0      1      0  71.2833      1        C
# 2         1       3  female  26.0      0      0   7.9250      0        S
# 3         1       1  female  35.0      1      0  53.1000      1        S
# 4         0       3    male  35.0      0      0   8.0500      0        S

# %%
# now we will do LAbel encoding as due to categorical data

from sklearn.preprocessing import LabelEncoder

label_ecoder = LabelEncoder()

# %%
label_ecoder.fit(titanic['Gender'])
# Out:
# LabelEncoder()

# %%
titanic['Gender'] = label_ecoder.transform(titanic['Gender'])

# %%
from sklearn.preprocessing import OneHotEncoder

one_hot_encoder = OneHotEncoder()

one_hot_encoder.fit(titanic[['Embarked']])
# Out:
# OneHotEncoder()

# %%
one_hot_encoder.transform(titanic[['Embarked']])
# Out:
# <889x3 sparse matrix of type '<class 'numpy.float64'>'
# 	with 889 stored elements in Compressed Sparse Row format>

# %%
temp = one_hot_encoder.transform(titanic[['Embarked']]).toarray()

# %%
one_hot_encoder.categories_
# Out:
# [array(['C', 'Q', 'S'], dtype=object)]

# %%
temp_df = pd.DataFrame(temp,columns=['C', 'Q', 'S'],dtype = int)

# %%
temp_df.head()
# Out:
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
titanic = pd.concat([titanic,temp_df],axis=1)

# %%
titanic.drop('Embarked',axis=1,inplace=True)

# %%
titanic.head()
# Out:
#    Survived  Pclass  Gender   Age  SibSp  Parch     Fare  Cabin  C  Q  S
# 0         0       3       1  22.0      1      0   7.2500      0  0  0  1
# 1         1       1       0  38.0      1      0  71.2833      1  1  0  0
# 2         1       3       0  26.0      0      0   7.9250      0  0  0  1
# 3         1       1       0  35.0      1      0  53.1000      1  0  0  1
# 4         0       3       1  35.0      0      0   8.0500      0  0  0  1

# %%
X = titanic.drop('Survived',axis=1)
Y = titanic['Survived']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

logistic_regression = LogisticRegression()

# %%
logistic_regression.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predicitons = logistic_regression.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

print(confusion_matrix(predicitons,Y_test))
# Out:
# [[97 22]
#  [10 49]]

# %%
print(classification_report(predicitons,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.86       119
#            1       0.69      0.83      0.75        59
#
#     accuracy                           0.82       178
#    macro avg       0.80      0.82      0.81       178
# weighted avg       0.83      0.82      0.82       178

# %%
## P
